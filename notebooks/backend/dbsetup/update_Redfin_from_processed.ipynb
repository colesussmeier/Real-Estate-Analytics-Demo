# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../../data/processed/Redfin/Redfin_April24_Processed.csv', dtype=str)

# %%
df.columns = ['ZipCode', 'Date', 'MedianSalePrice', 'MedianListPrice', 'HomesSold', 'NewListings', 'Inventory']
df['PendingSales'] = 0
df = df[['Date', 'ZipCode', 'MedianSalePrice', 'MedianListPrice', 'HomesSold', 'PendingSales', 'NewListings', 'Inventory']]

# %%
df = df[df['Date'] > '2022-12-31']

# %%
df
# Out:
#                Date ZipCode MedianSalePrice MedianListPrice HomesSold  \
# 84       2023-01-31   44815             NaN             NaN       NaN
# 85       2023-02-28   44815             NaN             NaN       NaN
# 86       2023-03-31   44815             NaN             NaN       NaN
# 87       2023-04-30   44815             NaN             NaN       NaN
# 88       2023-05-31   44815             NaN             NaN       NaN
# ...             ...     ...             ...             ...       ...
# 1931395  2023-12-31   17765         79000.0         74950.0       1.0
# 1931396  2024-01-31   17765             NaN             NaN       NaN
# 1931397  2024-02-29   17765         77500.0         95000.0       2.0
# 1931398  2024-03-31   17765         77500.0        172450.0       2.0
# 1931399  2024-04-30   17765        120000.0        249900.0       3.0
#
#          PendingSales NewListings Inventory
# 84                  0         NaN       NaN
# ...

# %%
df.to_csv('../../../data/site/Redfin_Update_April24_1yr.csv', index= False)
