# %%
# modified to add locations and prep for database

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/ZHVI/ZHVI_April24.csv', dtype=str)

# %% [markdown]
# ## Transpose date columns

# %% [markdown]
# Assumption is that there is an entry for every month and every zipcode... this must be true since the date columns all exist (empty values are nan)

# %%
# predetermine size of array
# 3 arrays of length: (# of timeseries entries (date columms)) * # unique zips
arr = np.empty([3,(len(df.columns) - 9) * df['RegionName'].nunique()], dtype=object)

# %%
a = 0
b = (len(df.columns) - 9)

# for every zip, transpose date columns and repeat zip code in 3rd column
for ind, row in df.iterrows():
  timeseries = row.iloc[9:].T

  arr[0,a:b] = timeseries.index.values
  arr[1,a:b] = timeseries.values
  arr[2,a:b] = np.repeat(row['RegionName'], len(timeseries.index.values))
  a += len(timeseries)# length of time in dataset
  b += len(timeseries)

# %%
temp_df = pd.DataFrame(arr.T)
temp_df.columns = ['Date', 'ZHVI', 'ZipCode']

# %%
temp_df
# Out:
#                Date                ZHVI ZipCode
# 0        2000-01-31  213463.22176577282   77494
# 1        2000-02-29  213648.48856106598   77494
# 2        2000-03-31   214143.5435946286   77494
# 3        2000-04-30  215143.44785558843   77494
# 4        2000-05-31  215179.21426169714   77494
# ...             ...                 ...     ...
# 7693611  2023-12-31  196271.14791287834   50160
# 7693612  2024-01-31  197149.51056180146   50160
# 7693613  2024-02-29  197990.45808887473   50160
# 7693614  2024-03-31  199040.41287595208   50160
# 7693615  2024-04-30  200208.12592839097   50160
#
# [7693616 rows x 3 columns]

# %%
df.iloc[:,1:9]
# Out:
#       SizeRank RegionName RegionType StateName State         City  \
# 0            1      77494        zip        TX    TX         Katy
# 1            2      08701        zip        NJ    NJ     Lakewood
# 2            3      77449        zip        TX    TX         Katy
# 3            4      11368        zip        NY    NY     New York
# 4            5      77084        zip        TX    TX      Houston
# ...        ...        ...        ...       ...   ...          ...
# 26343    39992      52163        zip        IA    IA     Protivin
# 26344    39992      46799        zip        IN    IN   Zanesville
# 26345    39992      22731        zip        VA    VA        Aroda
# 26346    39992      26576        zip        WV    WV   Farmington
# 26347    39992      50160        zip        IA    IA  Martensdale
#
#                                               Metro        CountyName
# 0              Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 1             New York-Newark-Jersey City, NY-NJ-PA      Ocean County
# 2              Houston-The Woodlands-Sugar Land, TX     Harris County
# 3             New York-Newark-Jersey City, NY-NJ-PA     Queens County
# 4              Houston-The Woodlands-Sugar Land, TX     Harris County
# ...                                             ...               ...
# 26343                                           NaN     Howard County
# 26344                                  Bluffton, IN      Wells County
# 26345  Washington-Arlington-Alexandria, DC-VA-MD-WV    Madison County
# 26346                                  Fairmont, WV     Marion County
# 26347                Des Moines-West Des Moines, IA     Warren County
#
# [26348 rows x 8 columns]

# %%
df = temp_df.merge(df.iloc[:,1:9], how='left', left_on='ZipCode', right_on='RegionName')

# %%
df
# Out:
#                Date                ZHVI ZipCode SizeRank RegionName  \
# 0        2000-01-31  213463.22176577282   77494        1      77494
# 1        2000-02-29  213648.48856106598   77494        1      77494
# 2        2000-03-31   214143.5435946286   77494        1      77494
# 3        2000-04-30  215143.44785558843   77494        1      77494
# 4        2000-05-31  215179.21426169714   77494        1      77494
# ...             ...                 ...     ...      ...        ...
# 7693611  2023-12-31  196271.14791287834   50160    39992      50160
# 7693612  2024-01-31  197149.51056180146   50160    39992      50160
# 7693613  2024-02-29  197990.45808887473   50160    39992      50160
# 7693614  2024-03-31  199040.41287595208   50160    39992      50160
# 7693615  2024-04-30  200208.12592839097   50160    39992      50160
#
#         RegionType StateName State         City  \
# 0              zip        TX    TX         Katy
# 1              zip        TX    TX         Katy
# 2              zip        TX    TX         Katy
# 3              zip        TX    TX         Katy
# 4              zip        TX    TX         Katy
# ...            ...       ...   ...          ...
# 7693611        zip        IA    IA  Martensdale
# 7693612        zip        IA    IA  Martensdale
# 7693613        zip        IA    IA  Martensdale
# 7693614        zip        IA    IA  Martensdale
# 7693615        zip        IA    IA  Martensdale
#
#                                         Metro        CountyName
# 0        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 1        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 2        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 3        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 4        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# ...                                       ...               ...
# 7693611        Des Moines-West Des Moines, IA     Warren County
# 7693612        Des Moines-West Des Moines, IA     Warren County
# 7693613        Des Moines-West Des Moines, IA     Warren County
# 7693614        Des Moines-West Des Moines, IA     Warren County
# 7693615        Des Moines-West Des Moines, IA     Warren County
#
# [7693616 rows x 11 columns]

# %%
df = df.drop(['RegionName', 'RegionType', 'StateName'], axis=1)

# %%
df.to_csv('../../data/formatted/ZHVI/ZHVI_April24_Formatted.csv', index= False)

# %% [markdown]
# ## Align location name with uszipcode directory
#
# Location names given by Zillow don't always match location names based off the zip code when searched through uszipcode. Match location names so that it is accurate when being searched on the realestatetimeseries.com site.

# %%
# %pip install uszipcode
# Out:
# Requirement already satisfied: uszipcode in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.1)
# Requirement already satisfied: attrs in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (23.1.0)
# Requirement already satisfied: requests in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (2.28.1)
# Requirement already satisfied: pathlib-mate in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (1.2.1)
# Requirement already satisfied: atomicwrites in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (1.4.1)
# Requirement already satisfied: fuzzywuzzy in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (0.18.0)
# Requirement already satisfied: haversine>=2.5.0 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (2.8.0)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (1.4.48)
# Requirement already satisfied: sqlalchemy-mate>=1.4.28.3 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uszipcode) (1.4.28.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.0->uszipcode) (2.0.2)
# Requirement already satisfied: prettytable in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy-mate>=1.4.28.3->uszipcode) (3.8.0)
# Requirement already satisfied: six in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pathlib-mate->uszipcode) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->uszipcode) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->uszipcode) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->uszipcode) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->uszipcode) (2022.12.7)
# Requirement already satisfied: wcwidth in c:\users\steve\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prettytable->sqlalchemy-mate>=1.4.28.3->uszipcode) (0.2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: C:\Users\Steve\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from uszipcode import SearchEngine

sr = SearchEngine()
# Out:
# C:\Users\Steve\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
zips = df['ZipCode'].unique()
zips = pd.DataFrame(zips, columns=['Zip'])
zips
# Out:
#          Zip
# 0      77494
# 1      08701
# 2      77449
# 3      11368
# 4      77084
# ...      ...
# 26343  52163
# 26344  46799
# 26345  22731
# 26346  26576
# 26347  50160
#
# [26348 rows x 1 columns]

# %%
zips['Location'] = zips.apply(lambda x: sr.by_zipcode(x['Zip']).major_city + ', ' + sr.by_zipcode(x['Zip']).state + " " + str(x['Zip']), axis=1)

# %%
df = df.merge(zips, how='inner', left_on='ZipCode', right_on='Zip')

# %%
df = df.drop(['Zip'], axis=1)
df
# Out:
#                Date                ZHVI ZipCode SizeRank State         City  \
# 0        2000-01-31  213463.22176577282   77494        1    TX         Katy
# 1        2000-02-29  213648.48856106598   77494        1    TX         Katy
# 2        2000-03-31   214143.5435946286   77494        1    TX         Katy
# 3        2000-04-30  215143.44785558843   77494        1    TX         Katy
# 4        2000-05-31  215179.21426169714   77494        1    TX         Katy
# ...             ...                 ...     ...      ...   ...          ...
# 7693611  2023-12-31  196271.14791287834   50160    39992    IA  Martensdale
# 7693612  2024-01-31  197149.51056180146   50160    39992    IA  Martensdale
# 7693613  2024-02-29  197990.45808887473   50160    39992    IA  Martensdale
# 7693614  2024-03-31  199040.41287595208   50160    39992    IA  Martensdale
# 7693615  2024-04-30  200208.12592839097   50160    39992    IA  Martensdale
#
#                                         Metro        CountyName  \
# 0        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 1        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 2        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 3        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 4        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# ...                                       ...               ...
# 7693611        Des Moines-West Des Moines, IA     Warren County
# 7693612        Des Moines-West Des Moines, IA     Warren County
# 7693613        Des Moines-West Des Moines, IA     Warren County
# 7693614        Des Moines-West Des Moines, IA     Warren County
# 7693615        Des Moines-West Des Moines, IA     Warren County
#
#                       Location
# 0               Katy, TX 77494
# 1               Katy, TX 77494
# 2               Katy, TX 77494
# 3               Katy, TX 77494
# 4               Katy, TX 77494
# ...                        ...
# 7693611  Martensdale, IA 50160
# 7693612  Martensdale, IA 50160
# 7693613  Martensdale, IA 50160
# 7693614  Martensdale, IA 50160
# 7693615  Martensdale, IA 50160
#
# [7693616 rows x 9 columns]

# %%
df['ZHVI'] = df['ZHVI'].astype(float)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['ZHVI'] = df['ZHVI'].round()

# %%
df
# Out:
#               Date      ZHVI ZipCode SizeRank State         City  \
# 0       2000-01-31  213463.0   77494        1    TX         Katy
# 1       2000-02-29  213648.0   77494        1    TX         Katy
# 2       2000-03-31  214144.0   77494        1    TX         Katy
# 3       2000-04-30  215143.0   77494        1    TX         Katy
# 4       2000-05-31  215179.0   77494        1    TX         Katy
# ...            ...       ...     ...      ...   ...          ...
# 7693611 2023-12-31  196271.0   50160    39992    IA  Martensdale
# 7693612 2024-01-31  197150.0   50160    39992    IA  Martensdale
# 7693613 2024-02-29  197990.0   50160    39992    IA  Martensdale
# 7693614 2024-03-31  199040.0   50160    39992    IA  Martensdale
# 7693615 2024-04-30  200208.0   50160    39992    IA  Martensdale
#
#                                         Metro        CountyName  \
# 0        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 1        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 2        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 3        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 4        Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# ...                                       ...               ...
# 7693611        Des Moines-West Des Moines, IA     Warren County
# 7693612        Des Moines-West Des Moines, IA     Warren County
# 7693613        Des Moines-West Des Moines, IA     Warren County
# 7693614        Des Moines-West Des Moines, IA     Warren County
# 7693615        Des Moines-West Des Moines, IA     Warren County
#
#                       Location
# 0               Katy, TX 77494
# 1               Katy, TX 77494
# 2               Katy, TX 77494
# 3               Katy, TX 77494
# 4               Katy, TX 77494
# ...                        ...
# 7693611  Martensdale, IA 50160
# 7693612  Martensdale, IA 50160
# 7693613  Martensdale, IA 50160
# 7693614  Martensdale, IA 50160
# 7693615  Martensdale, IA 50160
#
# [7693616 rows x 9 columns]

# %%
ZHVI_Table_May23 = df[['Date', 'ZHVI', 'ZipCode']]

# %%
Locations_Table_May23 = df.iloc[:,2:].drop_duplicates()

# %%
Locations_Json_May23 = df[['ZipCode', 'Location']].drop_duplicates()

# %%
ZHVI_Table_May23.to_csv('../../data/site/ZHVI_Table_April24.csv', index=False)

# %%
Locations_Table_May23.to_csv('../../data/site/Locations_Table_April24.tsv', sep='\t', index=False)

# %%
Locations_Json_May23.to_json('locations_April24.json', orient='records')
